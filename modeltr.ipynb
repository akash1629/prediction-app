# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Algerian_forest_fires_cleaned_dataset.csv')
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# ...

# %%
df.info(),df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB
# (None,
#  Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df["Classes"]=df["Classes"].str.strip()
#if want to do encoding of ategorical values then

# %%
df["Classes"]= df["Classes"].map({'not fire':0,'fire':1})
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes  Region
# 0  0.5        0       0
# 1  0.4        0       0
# 2  0.1        0       0
# 3  0.0        0       0
# 4  0.5        0       0

# %%
x=df.drop(columns=['FWI','day', 'month', 'year','DC'])
y=df['FWI']

# %%
x.head(), y.head()
# Out:
# (   Temperature  RH  Ws  Rain  FFMC  DMC  ISI  BUI  Classes  Region
#  0           29  57  18   0.0  65.7  3.4  1.3  3.4        0       0
#  1           29  61  13   1.3  64.4  4.1  1.0  3.9        0       0
#  2           26  82  22  13.1  47.1  2.5  0.3  2.7        0       0
#  3           25  89  13   2.5  28.6  1.3  0.0  1.7        0       0
#  4           27  77  16   0.0  64.8  3.0  1.2  3.9        0       0,
#  0    0.5
#  1    0.4
#  2    0.1
#  3    0.0
#  4    0.5
#  Name: FWI, dtype: float64)

# %%
#traintest split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x.shape,y.shape
# Out:
# ((243, 10), (243,))

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((182, 10), (61, 10), (182,), (61,))

# %%
#now here look carefully for selection of features is important before training the model
#there are many features that are correlated to each other those independent ones,
#our target is y so any depend on y is ok, but if within x features they are not ok to be realted ,as no meaning of them if they are similar
#or related or close to each other
#we have to drop correlateed features 
df.corr()
x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                   ISI       BUI   Classes    Region
# Temperature  0.629848  0.473609  0.542141  0.254549
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(x_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
#make a matrix of this corr
def correlation(data,threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = data.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:  # threshold for correlation
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold--Domain expertise
corr_features=correlation(x_train,0.85)

# %%
## drop features when correlation is more than 0.85 
x_train.drop(corr_features,axis=1,inplace=True)
x_test.drop(corr_features,axis=1,inplace=True)
x_train.shape,x_test.shape
# Out:
# ((182, 9), (61, 9))

# %%
#do standard scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled=scaler.fit_transform(x_train)
x_tes=scaler.transform(x_test)

# %%
#train model
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
new=model.fit(x_scaled,y_train)
y_pred=new.predict(x_tes)

# %%
from sklearn.metrics import mean_absolute_error
mea=mean_absolute_error(y_test,y_pred)
mea
# Out:
# 0.5468236465249978

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV()
lassocv.fit(x_scaled,y_train)
y_pred=lassocv.predict(x_tes)

# %%
import pickle
pickle.dump(scaler,open("scaler.pkl","wb"))
pickle.dump(lassocv,open("lassocv.pkl","wb"))
